# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Salary.csv")

# %%
df.head()
# Out:
#    Age  Salary  Experience
# 0   50   42717          13
# 1   36   99676          19
# 2   29   67952           2
# 3   42   82460           2
# 4   40  112847           8

# %%
df.shape
# Out:
# (29, 3)

# %%
df.isnull().sum()
# Out:
# Age           0
# Salary        0
# Experience    0
# dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(data=df.corr(),annot=True)
plt.show()
#Cheak the correlation of age and experience with salary individually in both graphs

# %%
x = df[["Experience","Age"]]
x
# Out:
#     Experience  Age
# 0           13   50
# 1           19   36
# 2            2   29
# 3            2   42
# 4            8   40
# 5            5   44
# 6           12   32
# 7            1   32
# 8            7   45
# 9            1   57
# 10           3   45
# 11          14   24
# 12           3   43
# 13          12   23
# 14          16   23
# 15           4   29
# 16          19   47
# 17           7   49
# 18          13   41
# 19           3   51
# 20          10   32
# 21          19   49
# 22          14   45
# 23          18   54
# 24           6   22
# 25          18   48
# 26          18   34
# 27          10   24
# 28           4   27

# %%
y = df["Salary"]
y
# Out:
# 0      42717
# 1      99676
# 2      67952
# 3      82460
# 4     112847
# 5      58449
# 6      73536
# 7     104077
# 8      78588
# 9      88302
# 10     68865
# 11     46645
# 12     78000
# 13     66737
# 14     97492
# 15     93002
# 16    112355
# 17     64762
# 18     51046
# 19     68769
# 20     93302
# 21     63150
# 22    108247
# 23     44853
# 24     61792
# 25     99192
# 26    114478
# 27    107298
# 28     71987
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 1.4351467112782235

# %%
lr.coef_ # m
# Out:
# array([ 387.29758125, -136.55587439])

# %%
lr.intercept_ #c
# Out:
# 82113.22464916956

# %%
x.columns
# Out:
# Index(['Experience', 'Age'], dtype='object')

# %%
y_pred = (13*387.29758125)+(50*(-136.55587439))+82113.22464916956
y_pred
# Out:
# 80320.29948591956

# %%
lr.predict(x_test)
# Out:
# array([85169.20083818, 82780.64084776, 81549.30235539, 81616.41248116,
#        82529.8991409 , 76310.76779897])

# %%
# It just for learning there is no problem of accuracy and all
