# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.drop(columns=['Pregnancies', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age'],inplace=True)

# %%
df
# Out:
#      Glucose  Outcome
# 0        148        1
# 1         85        0
# 2        183        1
# 3         89        0
# 4        137        1
# ..       ...      ...
# 763      101        0
# 764      122        0
# 765      121        0
# 766      126        1
# 767       93        0
#
# [768 rows x 2 columns]

# %%
sns.scatterplot(x="Glucose", y="Outcome", data=df)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[["Glucose"]]

# %%
y = df["Outcome"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 75.32467532467533

# %%
lr.predict([[148]]) #If glucose is 148 ?
# Out:
# C:\Users\PALLAVI\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
sns.scatterplot(x="Glucose", y="Outcome", data=df)
sns.lineplot(x ="Glucose", y=lr.predict(x),data=df, color='red')
plt.show()
