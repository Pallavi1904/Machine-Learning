# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import seaborn as sns

# %%
x,y = make_moons(n_samples=10000,noise=0.07)

# %%
df = {"x1":x[:,0], "x2":x[:,1], "y":y}

# %%
data = pd.DataFrame(df)

# %%
data
# Out:
#             x1        x2  y
# 0     0.515358 -0.332016  1
# 1     0.623336  0.848035  0
# 2    -0.314339  1.087859  0
# 3     0.555562  0.862525  0
# 4     1.316736 -0.438886  1
# ...        ...       ... ..
# 9995  0.202761  1.000276  0
# 9996  0.010879  0.236863  1
# 9997 -0.710934  0.660458  0
# 9998  0.402864 -0.320117  1
# 9999  1.292465 -0.328758  1
#
# [10000 rows x 3 columns]

# %%
sns.scatterplot(x="x1", y="x2", data=data, hue="y")
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
x_a = data.iloc[:,:-1]
y_a = data["y"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_a, y_a, test_size=0.2, random_state=42)

# %% [markdown]
# # Bagging Meta Estimator

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC

# %%
bg = BaggingClassifier(estimator=SVC(),n_estimators=30) #estimator value is imp
bg.fit(x_train, y_train) 
# Tr by direct SVC and cheak score
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=30)

# %%
bg.score(x_train, y_train)*100 , bg.score(x_test, y_test)*100
# Out:
# (100.0, 99.95)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=30)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
rf.score(x_train, y_train)*100 , rf.score(x_test, y_test)*100
# Out:
# (100.0, 99.85000000000001)
