# %%
 import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("temperatures.csv")

# %%
df.head(4)
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40

# %%
df.isnull().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
sns.distplot(df["ANNUAL"])
plt.show()
# Out:
# C:\Users\PALLAVI\AppData\Local\Temp\ipykernel_4384\1006012362.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["ANNUAL"])

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard = StandardScaler()

# %%
standard.fit(df[["ANNUAL"]])
# Out:
# StandardScaler()

# %%
df["ANNUAL_standard"] = pd.DataFrame(standard.transform(df[["ANNUAL"]]))

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC    ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC  ANNUAL_standard
# 0  27.31  24.49 -0.400176    23.27    31.46    31.27    27.25        -0.400176
# 1  26.31  24.04  0.069838    25.75    31.76    31.09    26.49         0.069838
# 2  26.08  23.65 -1.285971    24.24    30.71    30.92    26.26        -1.285971
# 3  26.36  23.63 -1.249816    23.62    30.95    30.66    26.40        -1.249816
# 4  27.52  23.82 -1.593287    22.25    30.00    31.33    26.57        -1.593287

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %%
sns.distplot(df["ANNUAL_standard"])
plt.show()
# no change in nature of graph
# Out:
# C:\Users\PALLAVI\AppData\Local\Temp\ipykernel_4384\3977458758.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["ANNUAL_standard"])
