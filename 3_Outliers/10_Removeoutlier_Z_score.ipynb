# %%
 import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Loan payments data.csv")

# %%
df.head(4)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male

# %%
sns.boxplot(x="Principal", data=df)
plt.show()

# %%
# Distribution plot
sns.distplot(df["Principal"])
plt.show()
# Out:
# C:\Users\PALLAVI\AppData\Local\Temp\ipykernel_17944\2698181991.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Principal"])

# %%
# Remove outlier using range (m-36)

# %%
min_range = df["Principal"].mean() - (3* df["Principal"].std() )

# %%
max_range = df["Principal"].mean() + (3* df["Principal"].std() )

# %%
new_data = df[df["Principal"] <= max_range]

# %%
sns.boxplot(x="Principal", data=new_data)
plt.show()

# %%
# Dont try to remove more outliers as it can also remove imp features needed to train data
# try to remove max_range outliers

# %%
# Remove outliers using Z-score

# %%
z_score = (df["Principal"] - df["Principal"].mean()) / (df["Principal"].std())

# %%
z_score
# Out:
# 0      0.492883
# 1      0.492883
# 2      0.492883
# 3      0.492883
# 4      0.492883
#          ...
# 495    0.492883
# 496    0.492883
# 497   -1.242621
# 498    0.492883
# 499    0.492883
# Name: Principal, Length: 500, dtype: float64

# %%
z_score > 3
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Principal, Length: 500, dtype: bool

# %%
df["z_score"] = z_score # ADDED NEW COLUMN TO DF

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df[df["z_score"] < 3]
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
sns.boxplot(x="Principal", data=new_data)
plt.show()

# %%
# try for age
