# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"Salary.csv")

# %%
df.head()
# Out:
#    Age  Salary  Experience
# 0   50   42717          13
# 1   36   99676          19
# 2   29   67952           2
# 3   42   82460           2
# 4   40  112847           8

# %%
df.isnull().sum()
# Out:
# Age           0
# Salary        0
# Experience    0
# dtype: int64

# %%
x = df[["Age","Experience"]]
y =df["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=40)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test,y_test)*100
# Out:
# -37.875458075558164

# %%
for i in range(1,13):
    knn1 = KNeighborsRegressor(n_neighbors=i)
    knn1.fit(x_train, y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 100.0 -96.1641586822599
# 2 34.32845476293976 -4.1153509513334185
# 3 18.778467443538048 37.79697587399138
# 4 12.463310999279376 -17.79293739826755
# 5 4.053698414760598 -37.875458075558164
# 6 3.383515368458001 -41.499026473030256
# 7 6.9752764837105685 -45.91515052327437
# 8 9.75977640256832 -26.82176783089909
# 9 10.865970519549029 -33.03790899686285
# 10 9.014782927023502 -29.981943970526626
# 11 6.241949757450993 2.45459280826823
# 12 6.479461088443472 -0.8601956330700045

# %%
# Not......... try on another data
